# %%
import sys
# !{sys.executable} -m pip install --upgrade \
  google-api-python-client google-auth-httplib2 google-auth-oauthlib \
  youtube-transcript-api pytube yt-dlp pandas scikit-learn tqdm python-dotenv
# Out:
# ...
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# ...
#   Using cached python_dotenv-1.2.1-py3-none-any.whl.metadata (25 kB)
# ...
#    ---------------------------------------- 0.0/14.6 MB ? eta -:--:--
#    ---- ----------------------------------- 1.6/14.6 MB 8.4 MB/s eta 0:00:02
#    ---------- ----------------------------- 3.7/14.6 MB 8.7 MB/s eta 0:00:02
#    ----------------- ---------------------- 6.3/14.6 MB 9.9 MB/s eta 0:00:01
#    ------------------------- -------------- 9.2/14.6 MB 10.8 MB/s eta 0:00:01
#    -------------------------------- ------- 12.1/14.6 MB 11.3 MB/s eta 0:00:01
#    ---------------------------------------  14.4/14.6 MB 11.3 MB/s eta 0:00:01
#    ---------------------------------------  14.4/14.6 MB 11.3 MB/s eta 0:00:01
#    ---------------------------------------- 14.6/14.6 MB 9.7 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#    -------------------------------- ------- 2.6/3.2 MB 12.6 MB/s eta 0:00:01
# ...

# %%
import IPython, time
IPython.Application.instance().kernel.do_shutdown(restart=True)
# Out:
# {'status': 'ok', 'restart': True}

# %%
from googleapiclient.discovery import build
from youtube_transcript_api import YouTubeTranscriptApi
import os

# quick check
print("googleapiclient OK")
print("youtube_transcript_api OK")
# Out:
# googleapiclient OK
# youtube_transcript_api OK

# %%
# 🔐 Paste your key when prompted (it won't be shown or saved in the notebook)
import os
from getpass import getpass
from googleapiclient.discovery import build

if not os.getenv("YOUTUBE_API_KEY"):
    os.environ["YOUTUBE_API_KEY"] = getpass("Paste your YouTube Data API v3 key: ")

YOUTUBE_API_KEY = os.environ["YOUTUBE_API_KEY"]
yt = build("youtube", "v3", developerKey=YOUTUBE_API_KEY)
print("YouTube client ready ✅")
